# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the processed NTSB data
ntsb_data = pd.read_csv('../data/processed/ntsb_crash_reports_cleaned.csv', encoding='ISO-8859-1')

# Display the first few rows of the data to check it's loaded correctly
print("NTSB Data Overview:")
print(ntsb_data.head())

# Get basic info about the dataset (e.g., number of rows, columns, missing values)
print("\nNTSB Data Info:")
print(ntsb_data.info())

# Get summary statistics for numerical columns
print("\nSummary Statistics for Numerical Columns:")
print(ntsb_data.describe())

# Check for missing values
print("\nMissing Values in NTSB Data:")
print(ntsb_data.isnull().sum())

# Top 10 States by Frequency of Accidents
state_accidents = ntsb_data['State'].value_counts().head(10)
print("\nTop 10 States by Frequency of Accidents (NTSB Data):")
print(state_accidents)

# Total Injury Counts
total_injuries = ntsb_data[['FatalInjuryCount', 'SeriousInjuryCount', 'MinorInjuryCount']].sum()
print("\nTotal Injury Counts (NTSB Data):")
print(total_injuries)

# Visualize Top 10 States by Frequency of Accidents
plt.figure(figsize=(10, 6))
sns.barplot(x=state_accidents.index, y=state_accidents.values, palette='viridis')
plt.title("Top 10 States by Frequency of Accidents")
plt.xlabel("State")
plt.ylabel("Number of Accidents")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Visualize the Total Injury Counts
injury_counts = total_injuries.reset_index()
injury_counts.columns = ['Injury Type', 'Count']
plt.figure(figsize=(8, 5))
sns.barplot(x='Injury Type', y='Count', data=injury_counts, palette='magma')
plt.title("Total Injury Counts in NTSB Data")
plt.xlabel("Injury Type")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# For ASRS data, you can load and summarize similarly if you have it cleaned
asrs_data = pd.read_csv('../data/processed/asrs_reports_cleaned.csv')

# Display the first few rows of the ASRS data
print("\nASRS Data Overview:")
print(asrs_data.head())

# Summary statistics for ASRS data
print("\nSummary Statistics for ASRS Data:")
print(asrs_data.describe())

# Check for missing values in ASRS data
print("\nMissing Values in ASRS Data:")
print(asrs_data.isnull().sum())

# Example: Top 10 reported issues in ASRS Data
top_issues = asrs_data['Assessments'].value_counts().head(10)
print("\nTop 10 Reported Issues (ASRS Data):")
print(top_issues)

# Visualize Top 10 Reported Issues in ASRS
plt.figure(figsize=(10, 6))
sns.barplot(x=top_issues.index, y=top_issues.values, palette='inferno')
plt.title("Top 10 Reported Issues in ASRS Data")
plt.xlabel("Issue")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# NTSB Data Overview:
#   Ã¯Â»Â¿"NtsbNo" EventType    Mkey             EventDate        City  \
# 0     CEN25LA001       ACC  195246  2024-10-01T15:13:00Z   Englewood
# 1     CEN24LA379       ACC  195235  2024-09-24T16:15:00Z  Janesville
# 2     CEN24LA359       ACC  195148  2024-09-19T19:35:00Z     Boulder
# 3     CEN24LA351       ACC  195104  2024-09-11T10:46:00Z  Schaumburg
# 4     ERA24LA373       ACC  195078  2024-09-07T11:30:00Z     Griffin
#
#        State        Country ReportNo       N  HasSafetyRec  ... Scheduled  \
# 0   Colorado  United States      NaN  N756JY         False  ...       NaN
# 1  Wisconsin  United States      NaN  N281EA         False  ...       NaN
# 2   Colorado  United States      NaN  N202MM         False  ...       NaN
# 3   Illinois  United States      NaN  N1429T         False  ...       NaN
# 4    Georgia  United States      NaN  N5096R         False  ...       NaN
#
#   PurposeOfFlight  FAR  AirCraftDamage  WeatherCondition  Operator  \
# 0            PERS  091     Substantial               VMC       NaN
# 1            INST  091     Substantial               VMC       NaN
# 2            PERS  091     Substantial               VMC       NaN
# 3            INST  091     Substantial               VMC       NaN
# 4            PERS  091     Substantial               VMC       NaN
#
#   ReportStatus  RepGenFlag                                      DocketUrl  \
# 0    Completed       False  https://data.ntsb.gov/Docket?ProjectID=195246
# 1    Completed       False  https://data.ntsb.gov/Docket?ProjectID=195235
# 2    Completed       False  https://data.ntsb.gov/Docket?ProjectID=195148
# 3    Completed       False  https://data.ntsb.gov/Docket?ProjectID=195104
# 4    Completed       False  https://data.ntsb.gov/Docket?ProjectID=195078
#
#       DocketPublishDate
# 0  11/8/2024 7:00:00 PM
# 1  11/8/2024 7:00:00 PM
# 2  11/8/2024 7:00:00 PM
# 3  11/8/2024 7:00:00 PM
# 4  11/8/2024 7:00:00 PM
#
# [5 rows x 37 columns]
#
# NTSB Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61634 entries, 0 to 61633
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ã¯Â»Â¿"NtsbNo"       61634 non-null  object
#  1   EventType            61634 non-null  object
#  2   Mkey                 61634 non-null  int64
#  3   EventDate            61634 non-null  object
#  4   City                 61622 non-null  object
#  5   State                61028 non-null  object
#  6   Country              61342 non-null  object
#  7   ReportNo             158 non-null    object
#  8   N                    61632 non-null  object
#  9   HasSafetyRec         61634 non-null  bool
#  10  ReportType           61557 non-null  object
#  11  OriginalPublishDate  61615 non-null  object
#  12  HighestInjuryLevel   27972 non-null  object
#  13  FatalInjuryCount     61634 non-null  int64
#  14  SeriousInjuryCount   61634 non-null  int64
#  15  MinorInjuryCount     61634 non-null  int64
#  16  ProbableCause        61634 non-null  object
#  17  EventID              0 non-null      float64
#  18  Latitude             61634 non-null  float64
#  19  Longitude            61634 non-null  float64
#  20  Make                 61634 non-null  object
#  21  Model                61634 non-null  object
#  22  AirCraftCategory     61625 non-null  object
#  23  AirportID            38524 non-null  object
#  24  AirportName          39404 non-null  object
#  25  AmateurBuilt         61634 non-null  object
#  26  NumberOfEngines      60348 non-null  object
#  27  Scheduled            7087 non-null   object
#  28  PurposeOfFlight      59373 non-null  object
#  29  FAR                  61633 non-null  object
#  30  AirCraftDamage       60206 non-null  object
#  31  WeatherCondition     61634 non-null  object
#  32  Operator             29491 non-null  object
#  33  ReportStatus         61558 non-null  object
#  34  RepGenFlag           61634 non-null  bool
#  35  DocketUrl            22892 non-null  object
#  36  DocketPublishDate    22892 non-null  object
# dtypes: bool(2), float64(3), int64(4), object(28)
# memory usage: 16.6+ MB
# None
#
# Summary Statistics for Numerical Columns:
#                 Mkey  FatalInjuryCount  SeriousInjuryCount  MinorInjuryCount  \
# count   61634.000000      61634.000000        61634.000000      61634.000000
# mean    57758.907957          0.363355            0.196304          0.328406
# std     33564.200846          2.590067            0.821995          1.722030
# min      2292.000000          0.000000            0.000000          0.000000
# 25%     32540.250000          0.000000            0.000000          0.000000
# 50%     56708.500000          0.000000            0.000000          0.000000
# 75%     83147.750000          0.000000            0.000000          0.000000
# max    195246.000000        265.000000           81.000000        171.000000
#
#        EventID      Latitude     Longitude
# count      0.0  6.163400e+04  6.163400e+04
# mean       NaN  1.420181e+03 -1.541331e+02
# std        NaN  2.418412e+05  7.628102e+03
# min        NaN -7.801694e+01 -1.004241e+06
# 25%        NaN  3.282611e+01 -1.145090e+02
# 50%        NaN  3.766941e+01 -9.408146e+01
# 75%        NaN  4.216854e+01 -8.172033e+01
# max        NaN  4.351118e+07  1.741242e+02
#
# Missing Values in NTSB Data:
# Ã¯Â»Â¿"NtsbNo"             0
# EventType                  0
# Mkey                       0
# EventDate                  0
# City                      12
# State                    606
# Country                  292
# ReportNo               61476
# N                          2
# HasSafetyRec               0
# ReportType                77
# OriginalPublishDate       19
# HighestInjuryLevel     33662
# FatalInjuryCount           0
# SeriousInjuryCount         0
# MinorInjuryCount           0
# ProbableCause              0
# EventID                61634
# Latitude                   0
# Longitude                  0
# Make                       0
# Model                      0
# AirCraftCategory           9
# AirportID              23110
# AirportName            22230
# AmateurBuilt               0
# NumberOfEngines         1286
# Scheduled              54547
# PurposeOfFlight         2261
# FAR                        1
# AirCraftDamage          1428
# WeatherCondition           0
# Operator               32143
# ReportStatus              76
# RepGenFlag                 0
# DocketUrl              38742
# DocketPublishDate      38742
# dtype: int64
#
# Top 10 States by Frequency of Accidents (NTSB Data):
# State
# California    6306
# Texas         4405
# Florida       4338
# Alaska        4288
# Arizona       2236
# Colorado      2102
# Washington    1990
# Georgia       1524
# Michigan      1489
# Illinois      1480
# Name: count, dtype: int64
#
# Total Injury Counts (NTSB Data):
# FatalInjuryCount      22395
# SeriousInjuryCount    12099
# MinorInjuryCount      20241
# dtype: int64
# C:\Users\Mary\AppData\Local\Temp\ipykernel_24144\1822993313.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=state_accidents.index, y=state_accidents.values, palette='viridis')
# C:\Users\Mary\AppData\Local\Temp\ipykernel_24144\1822993313.py:48: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Injury Type', y='Count', data=injury_counts, palette='magma')
# ASRS Data Overview:
#              Time             Time.1             Place          Place.1  \
# 0     ACN    Date  Local Time Of Day  Locale Reference  State Reference
# 1  260353  199401          0601-1200               BUF               NY
# 2  261253  199401          1801-2400               MBS               MI
# 3  261326  199401          1201-1800               FTG               CO
# 4  261567  199401          1201-1800               NTD               CA
#
#                           Place.2                                    Place.3  \
# 0  Relative Position.Angle.Radial  Relative Position.Distance.Nautical Miles
# 1                             272                                        NaN
# 2                             NaN                                          3
# 3                             NaN                                        NaN
# 4                             NaN                                          2
#
#                      Place.4                    Place.5  \
# 0  Altitude.AGL.Single Value  Altitude.MSL.Single Value
# 1                        NaN                       3500
# 2                        NaN                       8500
# 3                          0                        NaN
# 4                        NaN                       1700
#
#                       Place.6  ...                          Person 2.10  \
# 0  Latitude / Longitude (UAS)  ...  ASRS Report Number.Accession Number
# 1                         NaN  ...                                  NaN
# 2                         NaN  ...                                  NaN
# 3                         NaN  ...                               261329
# 4                         NaN  ...                                  NaN
#
#                                               Events         Events.1  \
# 0                                            Anomaly    Miss Distance
# 1  Aircraft Equipment Problem Critical; Deviation...              NaN
# 2  Aircraft Equipment Problem Critical; Other Uns...              NaN
# 3  Aircraft Equipment Problem Critical; Inflight ...              NaN
# 4  Aircraft Equipment Problem Less Severe; Confli...  Horizontal 1000
#
#                             Events.2  \
# 0  Were Passengers Involved In Event
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#                                             Events.3       Events.4  \
# 0                                           Detector  When Detected
# 1                                 Person Flight Crew            NaN
# 2  Automation Aircraft Other Automation; Person F...            NaN
# 3                                 Person Flight Crew            NaN
# 4     Person Air Traffic Control; Person Flight Crew            NaN
#
#                                             Events.5  \
# 0                                             Result
# 1                         General Declared Emergency
# 2                                                NaN
# 3  Aircraft Aircraft Damaged; General None Report...
# 4  Flight Crew Executed Go Around / Missed Approa...
#
#                          Assessments    Assessments.1  \
# 0  Contributing Factors / Situations  Primary Problem
# 1                                NaN         Aircraft
# 2                                NaN         Aircraft
# 3                                NaN    Human Factors
# 4                          Procedure    Human Factors
#
#                                           Report 1.2
# 0                                           Synopsis
# 1  PRIMARY ELECTRICAL SUPPLY PROB. LOSS OF COM FR...
# 2  FLT INSTRUCTOR WHO WAS A DESIGNATED PLT EXAMIN...
# 3  DURING SECOND STUDENT SOLO LNDG; THE NOSE GEAR...
# 4  POTENTIAL CONFLICT LESSENED BY PLT RESPONSE IN...
#
# [5 rows x 121 columns]
#
# Summary Statistics for ASRS Data:
#                 Time     Time.1        Place Place.1 Place.2 Place.3 Place.4  \
# count   2427    2427       2354         2427    2425     330    1188     940
# unique  2427     365          5          794      56     123      83      53
# top      ACN  202206  1201-1800  ZZZ.Airport      US     270       0       0
# freq       1      19       1152         1175    1457      15     243     640
#
#        Place.5                     Place.6  ...  \
# count     1377                           1  ...
# unique     122                           1  ...
# top       3000  Latitude / Longitude (UAS)  ...
# freq       110                           1  ...
#
#                                 Person 2.10  \
# count                                   165
# unique                                  165
# top     ASRS Report Number.Accession Number
# freq                                      1
#
#                                      Events                  Events.1  \
# count                                  2427                        80
# unique                                  905                        66
# top     Aircraft Equipment Problem Critical  Horizontal 0; Vertical 0
# freq                                    467                         3
#
#        Events.2            Events.3   Events.4                       Events.5  \
# count       239                2383       1284                           2350
# unique        3                  32         35                            923
# top           N  Person Flight Crew  In-flight  General None Reported / Taken
# freq        207                1824       1126                            209
#
#        Assessments Assessments.1 Report 1.2
# count         2075          2389       2427
# unique         249            16       2427
# top       Aircraft      Aircraft   Synopsis
# freq           805          1476          1
#
# [4 rows x 121 columns]
#
# Missing Values in ASRS Data:
#                     0
# Time                0
# Time.1             73
# Place               0
# Place.1             2
#                  ...
# Events.4         1143
# Events.5           77
# Assessments       352
# Assessments.1      38
# Report 1.2          0
# Length: 121, dtype: int64
#
# Top 10 Reported Issues (ASRS Data):
# Assessments
# Aircraft                              805
# Aircraft; Human Factors               422
# Human Factors; Aircraft               129
# Human Factors                         106
# Aircraft; Human Factors; Weather       37
# Aircraft; Human Factors; Procedure     36
# Aircraft; Weather                      22
# Aircraft; Procedure                    15
# Weather; Aircraft                      15
# Human Factors; Aircraft; Procedure     14
# Name: count, dtype: int64
# C:\Users\Mary\AppData\Local\Temp\ipykernel_24144\1822993313.py:77: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_issues.index, y=top_issues.values, palette='inferno')
